# %%
library(tidyverse, verbose = FALSE)
library(lubridate, verbose = FALSE)
library(forecast, verbose = FALSE)
library(car, verbose = FALSE)
library(boot, verbose = FALSE)
library(zoo, verbose = FALSE)
library(ggplot2, verbose = FALSE)
library(factoextra, verbose = FALSE)
cities <- c(
  "New York", "Los Angeles", "Chicago", "Houston", "Phoenix",
  "Philadelphia", "San Antonio", "San Diego", "Dallas", "San Jose"
)
set.seed(5100)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 4.0.0     ✔ purrr   1.1.0
# ✔ tibble  3.3.0     ✔ dplyr   1.1.4
# ✔ tidyr   1.3.1     ✔ stringr 1.5.2
# ✔ readr   2.1.5     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ purrr::%||%()   masks base::%||%()
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# Attaching package: ‘lubridate’
#
#
# The following objects are masked from ‘package:base’:
#
#     date, intersect, setdiff, union
#
#
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo
#
# Loading required package: carData
#
#
# Attaching package: ‘car’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     recode
#
#
# The following object is masked from ‘package:purrr’:
#
#     some
#
#
#
# Attaching package: ‘boot’
#
#
# The following object is masked from ‘package:car’:
#
#     logit
#
#
#
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
#
# Welcome! Want to learn more? See two factoextra-related books at https://goo.gl/ve3WBa

# %% [markdown]
# # Load Pollutant Data

# %%
pm25_raw <- read_csv("../../data/daily_88101_2023.csv", show_col_types = FALSE)
o3_raw   <- read_csv("../../data/daily_44201_2023.csv", show_col_types = FALSE)
no2_raw  <- read_csv("../../data/daily_42602_2023.csv", show_col_types = FALSE)

clean_pollutant <- function(df, pollutant_name) {
  df %>%
    filter(`City Name` %in% cities) %>%          # filter ROWS by city name
    mutate(Date = ymd(`Date Local`)) %>%         # convert date
    select(`City Name`, Date, `Arithmetic Mean`) %>%  # select correct columns
    rename(
      City = `City Name`,
      !!pollutant_name := `Arithmetic Mean`
    )
} 

pm25 <- clean_pollutant(pm25_raw, "PM25")
o3   <- clean_pollutant(o3_raw,   "O3")
# Convert o3 from ppm to ppb
o3 <- o3 %>%
  mutate(O3 = O3 * 1000)
no2  <- clean_pollutant(no2_raw,  "NO2")

air_df <- pm25 %>%
  inner_join(o3, by = c("City", "Date")) %>%
  inner_join(no2, by = c("City", "Date"))

# There are duplicate rows as the indicators have multiple monitoring sites per city. 
air_df_clean <- air_df %>%
  group_by(City, Date) %>%
  summarise(
    PM25 = mean(PM25, na.rm = TRUE),
    O3   = mean(O3,   na.rm = TRUE),
    NO2  = mean(NO2,  na.rm = TRUE),
    .groups = "drop"
  ) %>%
  arrange(City, Date)

head(air_df_clean)
# Out:
# Warning message in inner_join(., o3, by = c("City", "Date")):
# “Detected an unexpected many-to-many relationship between `x` and `y`.
# ℹ Row 1 of `x` matches multiple rows in `y`.
# ℹ Row 12 of `y` matches multiple rows in `x`.
# ℹ If a many-to-many relationship is expected, set `relationship =
#   "many-to-many"` to silence this warning.”
# Warning message in inner_join(., no2, by = c("City", "Date")):
# “Detected an unexpected many-to-many relationship between `x` and `y`.
# ℹ Row 1 of `x` matches multiple rows in `y`.
# ℹ Row 12 of `y` matches multiple rows in `x`.
# ℹ If a many-to-many relationship is expected, set `relationship =
#   "many-to-many"` to silence this warning.”
#   City    Date       PM25      O3       NO2
# 1 Chicago 2023-03-01  9.166667 26.43133 15.797916
# 2 Chicago 2023-03-02  2.800000 36.49033  9.470833
# 3 Chicago 2023-03-04 16.100000 21.09800 19.579167
# 4 Chicago 2023-03-07  3.150000 38.09800  6.368750
# 5 Chicago 2023-03-10  3.300000 33.85300 10.012500
# 6 Chicago 2023-03-13  4.175000 32.26450 11.920265

# %% [markdown]
# ## Load Weather Data

# %%
# load weather data for all cities
city_weather_dfs <- list()
for (city in cities) {
    df <- read_csv(paste0("../../data/weather_data/", city, ".csv"), show_col_types = FALSE)

    # mutate date to not have time component
    df <- df %>%
      mutate(date = as.Date(date))

    city_weather_dfs[[city]] <- df
}

head(city_weather_dfs[["New York"]] )
# Out:
#   date       cloud_cover_mean relative_humidity_2m_mean wind_gusts_10m_mean
# 1 2023-01-01 42.54167         82.91020                  13.682983
# 2 2023-01-02 86.04166         84.02973                   7.372779
# 3 2023-01-03 99.79166         96.86331                  11.063829
# 4 2023-01-04 99.33334         94.22936                  12.014553
# 5 2023-01-05 96.75000         92.18182                   9.535212
# 6 2023-01-06 66.62500         85.81839                  11.352776
#   wind_speed_10m_mean precipitation_hours precipitation_sum temperature_2m_mean
# 1 7.770374             2                  0.04330709        47.62655
# 2 4.012463             3                  0.02362205        46.17905
# 3 6.264936             8                  0.37007874        49.25780
# 4 6.537843             5                  0.09055118        55.35905
# 5 5.195051             0                  0.00000000        49.65530
# 6 6.153474            14                  0.37795272        42.60155

# %% [markdown]
# ## New York City Only
#
# ### Shapiro Test - Check Normality

# %%
merge_weather_air <- function(city) {
  df <- city_weather_dfs[[city]]
  df <- df %>%
    inner_join(air_df_clean %>% filter(City == city), by = c("date" = "Date")) %>%
    select(date, temperature_2m_mean, cloud_cover_mean, relative_humidity_2m_mean, wind_gusts_10m_mean, wind_speed_10m_mean, precipitation_hours, precipitation_sum, PM25, O3, NO2)
  return(df)
}

# merge NY weather and air data
ny_df <- merge_weather_air("New York")

# check for missing values
colSums(is.na(ny_df))

# check if temperature is normally distributed
shapiro.test(ny_df$relative_humidity_2m_mean)
shapiro.test(ny_df$PM25)
shapiro.test(ny_df$O3)
shapiro.test(ny_df$NO2)
# Out:
#                      date       temperature_2m_mean          cloud_cover_mean
#                         0                         0                         0
# relative_humidity_2m_mean       wind_gusts_10m_mean       wind_speed_10m_mean
#                         0                         0                         0
#       precipitation_hours         precipitation_sum                      PM25
#                         0                         0                         0
#                        O3                       NO2
#                         0                         0
# 	Shapiro-Wilk normality test
#
# data:  ny_df$relative_humidity_2m_mean
# W = 0.98696, p-value = 0.002299
# 	Shapiro-Wilk normality test
#
# data:  ny_df$PM25
# W = 0.35725, p-value < 2.2e-16
# 	Shapiro-Wilk normality test
#
# data:  ny_df$O3
# W = 0.9962, p-value = 0.5344
# 	Shapiro-Wilk normality test
#
# data:  ny_df$NO2
# W = 0.91849, p-value = 3.576e-13

# %% [markdown]
# Temperature data, PM2.5, and NO3 data are not normally distributed, as the Shapiro Wilk normality test has a very low p-value for both variables. Therefore, we reject the null hypothesis that the data is normally distributed.
#
# However, O3 data appears to be normally distributed, as the Shapiro Wilk normality test has a high p-value. Therefore, we fail to reject the null hypothesis that the data is normally distributed.
#
# The approach is to split the temperature data into two groups -- high and low, based on the median temperature of the entire year. Then, we compare the PM2.5 levels between these two groups using the Wilcoxon rank-sum test.

# %% [markdown]
# ### Pollutant Plots

# %%
hist(ny_df$relative_humidity_2m_mean, main = "Histogram of Temperature", xlab = "Temperature (°F)", breaks = 20)
hist(ny_df$PM25, main = "Histogram of PM2.5", xlab = "PM2.5", breaks = 20)
hist(ny_df$O3, main = "Histogram of O3", xlab = "O3", breaks = 20)
hist(ny_df$NO2, main = "Histogram of NO2", xlab = "NO2", breaks = 20)
# Out:
# Plot with title “Histogram of Temperature”
# Plot with title “Histogram of PM2.5”
# Plot with title “Histogram of O3”
# Plot with title “Histogram of NO2”

# %% [markdown]
# ### Wilcoxon Rank-Sum Test

# %%
ny_df <- ny_df %>% filter(between(PM25, quantile(PM25, 0.05, na.rm = TRUE), quantile(PM25, 0.95, na.rm = TRUE))) 

median_temp <- median(ny_df$relative_humidity_2m_mean, na.rm = TRUE)
ny_df$high_temp <- ny_df$relative_humidity_2m_mean > median_temp
print(ny_df$high_temp)

wilcox.test(PM25 ~ high_temp, data = ny_df, conf.int = TRUE)
t.test(O3 ~ high_temp, data = ny_df, conf.int = TRUE)
wilcox.test(NO2 ~ high_temp, data = ny_df, conf.int = TRUE)
# Out:
#   [1]  TRUE  TRUE  TRUE  TRUE  TRUE FALSE FALSE  TRUE FALSE FALSE  TRUE  TRUE
#  [13] FALSE FALSE FALSE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE FALSE
#  [25] FALSE FALSE  TRUE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE
#  [37]  TRUE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE  TRUE FALSE  TRUE
#  [49]  TRUE  TRUE  TRUE  TRUE FALSE FALSE FALSE FALSE  TRUE  TRUE  TRUE  TRUE
#  [61] FALSE FALSE FALSE  TRUE  TRUE FALSE  TRUE FALSE FALSE FALSE FALSE FALSE
#  [73] FALSE FALSE FALSE  TRUE FALSE FALSE FALSE FALSE FALSE  TRUE  TRUE FALSE
#  [85]  TRUE  TRUE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE
#  [97]  TRUE FALSE FALSE FALSE FALSE  TRUE  TRUE  TRUE FALSE FALSE  TRUE  TRUE
# [109]  TRUE  TRUE  TRUE FALSE  TRUE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE
# [121] FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE  TRUE FALSE  TRUE  TRUE
# [133] FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE  TRUE FALSE  TRUE FALSE
# [145] FALSE FALSE FALSE FALSE  TRUE FALSE  TRUE FALSE  TRUE  TRUE FALSE  TRUE
# [157]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
# [169] FALSE FALSE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE FALSE FALSE
# [181]  TRUE  TRUE  TRUE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [193] FALSE  TRUE  TRUE FALSE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
# [205] FALSE FALSE FALSE FALSE FALSE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
# [217] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE  TRUE  TRUE
# [229]  TRUE  TRUE  TRUE FALSE FALSE FALSE FALSE  TRUE FALSE FALSE  TRUE  TRUE
# [241]  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
# [253]  TRUE  TRUE FALSE FALSE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE
# [265]  TRUE FALSE  TRUE FALSE FALSE FALSE  TRUE  TRUE FALSE FALSE FALSE  TRUE
# [277]  TRUE  TRUE  TRUE FALSE  TRUE  TRUE FALSE  TRUE  TRUE FALSE  TRUE  TRUE
# [289]  TRUE FALSE FALSE  TRUE  TRUE FALSE FALSE FALSE  TRUE  TRUE FALSE FALSE
# [301] FALSE  TRUE  TRUE  TRUE FALSE FALSE  TRUE  TRUE  TRUE  TRUE FALSE FALSE
# [313] FALSE FALSE  TRUE  TRUE  TRUE FALSE FALSE FALSE  TRUE  TRUE  TRUE  TRUE
# [325]  TRUE FALSE FALSE
# 	Wilcoxon rank sum test with continuity correction
#
# data:  PM25 by high_temp
# W = 9941.5, p-value = 6.185e-05
# alternative hypothesis: true location shift is not equal to 0
# 95 percent confidence interval:
#  -2.206164 -0.741960
# sample estimates:
# difference in location
#              -1.448873
# 	Welch Two Sample t-test
#
# data:  O3 by high_temp
# t = 4.1322, df = 324.18, p-value = 4.578e-05
# alternative hypothesis: true difference in means between group FALSE and group TRUE is not equal to 0
# 95 percent confidence interval:
#  2.558456 7.208293
# sample estimates:
# mean in group FALSE  mean in group TRUE
#            29.75329            24.86992
# 	Wilcoxon rank sum test with continuity correction
#
# data:  NO2 by high_temp
# W = 12125, p-value = 0.1467
# alternative hypothesis: true location shift is not equal to 0
# 95 percent confidence interval:
#  -2.3563129  0.3224211
# sample estimates:
# difference in location
#             -0.9812257

# %% [markdown]
# The p value of the Wilcoxon rank-sum test is very small, and we therefore conclude that there is a significant difference in PM2.5, O3, and NO2 levels between high and low temperature days in New York City. We now use bootstrapping to confirm our results.

# %% [markdown]
# ### Bootstrapping
#
# #### PM2.5

# %%
bootstrap <- function(df, pollutant, b){
  bootstrap_correlations <- numeric(b)
  for (i in 1:b){
    sample <- df[sample(nrow(df), replace = TRUE), ]
    bootstrap_correlations[i] <- cor(sample$relative_humidity_2m_mean, sample[[pollutant]], method = "spearman")
  }

  # actual correlation between pollutant and temperature
  actual_correlation <- cor(df$relative_humidity_2m_mean, df[[pollutant]], method = "spearman")

  # 95% confidence interval
  ci <- quantile(bootstrap_correlations, c(0.025, 0.975))

  round(actual_correlation, 3)
  round(ci, 3)
  
  # plot histogram of bootstrap correlations and mark actual correlation and confidence intervals
  m <- max(abs(c(bootstrap_correlations, actual_correlation, ci)))
  hist(bootstrap_correlations, main = paste("Bootstrap Correlations between Temperature and", pollutant), xlab = "Spearman Correlation", breaks = 30, xlim = c(-m, m))
  abline(v = actual_correlation, col = "red", lwd = 2)
  abline(v = ci[1], col = "blue", lwd = 2, lty = 2)
  abline(v = ci[2], col = "blue", lwd = 2, lty = 2)
  abline(v = 0, col = "black", lwd = 1, lty = 3)
  legend("topleft", legend = c("Actual Correlation", "95% CI"), col = c("red", "blue"), lwd = 2, lty = c(1,2))
  }

bootstrap(ny_df, "PM25", 1000)
# Out:
# Plot with title “Bootstrap Correlations between Temperature and PM25”

# %% [markdown]
# #### O3

# %%
bootstrap(ny_df, "O3", 1000)
# Out:
# Plot with title “Bootstrap Correlations between Temperature and O3”

# %% [markdown]
# #### NO2

# %%
bootstrap(ny_df, "NO2", 1000)
# Out:
# Plot with title “Bootstrap Correlations between Temperature and NO2”

# %% [markdown]
# ### Data Visualization

# %%
merge_weather_air <- function(city) {
  df <- city_weather_dfs[[city]]
  df <- df %>%
    inner_join(air_df_clean %>% filter(City == city), by = c("date" = "Date")) %>%
    select(date, relative_humidity_2m_mean_mean, cloud_cover_mean, relative_humidity_2m_mean, wind_gusts_10m_mean, wind_speed_10m_mean, precipitation_hours, precipitation_sum, PM25, O3, NO2)
  return(df)
}

total_df <- data.frame()
for (city in cities) {
    df <- merge_weather_air(city)
    total_df <- rbind(total_df, df)
}

## add temp high column
median_temp_all <- median(total_df$relative_humidity_2m_mean, na.rm = TRUE)
total_df$high_temp <- total_df$relative_humidity_2m_mean > median_temp_all

# %% [markdown]
# Repeat all the same analysis as with New York City
#
# ## All Cities
#
# ### Shapiro Test - Check Normality

# %%
shapiro.test(total_df$relative_humidity_2m_mean)
shapiro.test(total_df$PM25)
shapiro.test(total_df$O3)
shapiro.test(total_df$NO2)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  total_df$temperature_2m_mean
# W = 0.99458, p-value = 7.66e-10
# 	Shapiro-Wilk normality test
#
# data:  total_df$PM25
# W = 0.53658, p-value < 2.2e-16
# 	Shapiro-Wilk normality test
#
# data:  total_df$O3
# W = 0.9978, p-value = 0.0001036
# 	Shapiro-Wilk normality test
#
# data:  total_df$NO2
# W = 0.93596, p-value < 2.2e-16

# %% [markdown]
# When concatenating data from all cities, we find that temperature and all three pollutants are not normally distributed.

# %% [markdown]
# ### Wilcoxon Rank-Sum Test

# %% [markdown]
# ### PM2.5

# %%
wilcox.test(total_df$PM25 ~ total_df$high_temp, conf.int = TRUE)
wilcox.test(total_df$O3 ~ total_df$high_temp, conf.int = TRUE)
wilcox.test(total_df$NO2 ~ total_df$high_temp, conf.int = TRUE)
# Out:
# 	Wilcoxon rank sum test with continuity correction
#
# data:  total_df$PM25 by total_df$high_temp
# W = 1048592, p-value < 2.2e-16
# alternative hypothesis: true location shift is not equal to 0
# 95 percent confidence interval:
#  -2.212012 -1.640652
# sample estimates:
# difference in location
#              -1.924411
# 	Wilcoxon rank sum test with continuity correction
#
# data:  total_df$O3 by total_df$high_temp
# W = 790472, p-value < 2.2e-16
# alternative hypothesis: true location shift is not equal to 0
# 95 percent confidence interval:
#  -8.778133 -7.411710
# sample estimates:
# difference in location
#              -8.088546
# 	Wilcoxon rank sum test with continuity correction
#
# data:  total_df$NO2 by total_df$high_temp
# W = 1893656, p-value < 2.2e-16
# alternative hypothesis: true location shift is not equal to 0
# 95 percent confidence interval:
#  3.062450 3.857343
# sample estimates:
# difference in location
#               3.458981

# %% [markdown]
# ### Pollutant Plots

# %%
hist(total_df$relative_humidity_2m_mean, main = "Histogram of Temperature", xlab = "Temperature (°F)", breaks = 20)
hist(total_df$PM25, main = "Histogram of PM2.5", xlab = "PM2.5", breaks = 20)
hist(total_df$O3, main = "Histogram of O3", xlab = "O3", breaks = 20)
hist(total_df$NO2, main = "Histogram of NO2", xlab = "NO2", breaks = 20)
# Out:
# Plot with title “Histogram of Temperature”
# Plot with title “Histogram of PM2.5”
# Plot with title “Histogram of O3”
# Plot with title “Histogram of NO2”

# %% [markdown]
# ### Bootstrapping
#
# #### PM2.5

# %%
bootstrap <- function(df, pollutant, b){
  bootstrap_correlations <- numeric(b)
  for (i in 1:b){
    sample <- df[sample(nrow(df), replace = TRUE), ]
    bootstrap_correlations[i] <- cor(sample$relative_humidity_2m_mean_mean, sample[[pollutant]], method = "spearman")
  }

  # actual correlation between pollutant and temperature
  actual_correlation <- cor(df$temperature_2m_mean, df[[pollutant]], method = "spearman")

  # 95% confidence interval
  ci <- quantile(bootstrap_correlations, c(0.025, 0.975))

  round(actual_correlation, 3)
  round(ci, 3)
  
  # plot histogram of bootstrap correlations and mark actual correlation and confidence intervals
  m <- max(abs(c(bootstrap_correlations, actual_correlation, ci)))
  hist(bootstrap_correlations, main = paste("Bootstrap Correlations between Temperature and", pollutant), xlab = "Spearman Correlation", breaks = 30, xlim = c(-m, m))
  abline(v = actual_correlation, col = "red", lwd = 2)
  abline(v = ci[1], col = "blue", lwd = 2, lty = 2)
  abline(v = ci[2], col = "blue", lwd = 2, lty = 2)
  abline(v = 0, col = "black", lwd = 1, lty = 3)
  legend("topleft", legend = c("Actual Correlation", "95% CI"), col = c("red", "blue"), lwd = 2, lty = c(1,2))
  }

bootstrap(total_df, "PM25", 1000)
# Out:
# Plot with title “Bootstrap Correlations between Temperature and PM25”

# %% [markdown]
# #### O3

# %%
bootstrap(total_df, "O3", 1000)
# Out:
# Plot with title “Bootstrap Correlations between Temperature and O3”

# %% [markdown]
# #### NO2

# %%
bootstrap(total_df, "NO2", 1000)
# Out:
# Plot with title “Bootstrap Correlations between Temperature and NO2”
